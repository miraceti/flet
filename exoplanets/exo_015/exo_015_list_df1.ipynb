# %%
import pandas

# %%
import pandas as pd
import flet as ft
from urllib.request import urlopen
import json
import datetime

# %%
urlexo1 = "https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+count(pl_name)+as+nbe+from+ps+where+default_flag=1&format=json"
print(urlexo1)
data = json.loads(urlopen(urlexo1).read().decode("utf-8"))
# print(data)
data0=data[0]
# print(data0)
nb_exoplanets= data0['nbe']
print(nb_exoplanets)
# Out:
# https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+count(pl_name)+as+nbe+from+ps+where+default_flag=1&format=json
# 5788

# %%
urlexo7 = "https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+\
pl_name,hostname,pl_letter,pl_bmasse,pl_bmassj,pl_rade,pl_radj,pl_orbper,pl_dens,pl_trandur,pl_ratror,\
sy_snum,sy_pnum,sy_mnum,st_mass,st_lum,st_age,st_dens,sy_dist,disc_year,disc_telescope,discoverymethod,\
releasedate\
+from+ps+where+default_flag=1&format=json"

print(urlexo7)
list7 = json.loads(urlopen(urlexo7).read().decode("utf-8"))
#print(list7)
# Out:
# https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+pl_name,hostname,pl_letter,pl_bmasse,pl_bmassj,pl_rade,pl_radj,pl_orbper,pl_dens,pl_trandur,pl_ratror,sy_snum,sy_pnum,sy_mnum,st_mass,st_lum,st_age,st_dens,sy_dist,disc_year,disc_telescope,discoverymethod,releasedate+from+ps+where+default_flag=1&format=json

# %%
print(list7[0])
# Out:
# {'pl_name': 'OGLE-TR-10 b', 'hostname': 'OGLE-TR-10', 'pl_letter': 'b', 'pl_bmasse': 197.046, 'pl_bmassj': 0.62, 'pl_rade': 14.011, 'pl_radj': 1.25, 'pl_orbper': 3.101278, 'pl_dens': 0.4, 'pl_trandur': None, 'pl_ratror': None, 'sy_snum': 1, 'sy_pnum': 1, 'sy_mnum': 0, 'st_mass': 1.14, 'st_lum': 0.188, 'st_age': None, 'st_dens': None, 'sy_dist': 1344.97, 'disc_year': 2004, 'disc_telescope': '1.3 m Warsaw University Telescope', 'discoverymethod': 'Transit', 'releasedate': '2014-05-14'}

# %%
len(list7)
# Out:
# 5788

# %%
list7[0]
# Out:
# {'pl_name': 'OGLE-TR-10 b',
#  'hostname': 'OGLE-TR-10',
#  'pl_letter': 'b',
#  'pl_bmasse': 197.046,
#  'pl_bmassj': 0.62,
#  'pl_rade': 14.011,
#  'pl_radj': 1.25,
#  'pl_orbper': 3.101278,
#  'pl_dens': 0.4,
#  'pl_trandur': None,
#  'pl_ratror': None,
#  'sy_snum': 1,
#  'sy_pnum': 1,
#  'sy_mnum': 0,
#  'st_mass': 1.14,
#  'st_lum': 0.188,
#  'st_age': None,
#  'st_dens': None,
#  'sy_dist': 1344.97,
#  'disc_year': 2004,
#  'disc_telescope': '1.3 m Warsaw University Telescope',
#  'discoverymethod': 'Transit',
#  'releasedate': '2014-05-14'}

# %%
list7[0].keys()
# Out:
# dict_keys(['pl_name', 'hostname', 'pl_letter', 'pl_bmasse', 'pl_bmassj', 'pl_rade', 'pl_radj', 'pl_orbper', 'pl_dens', 'pl_trandur', 'pl_ratror', 'sy_snum', 'sy_pnum', 'sy_mnum', 'st_mass', 'st_lum', 'st_age', 'st_dens', 'sy_dist', 'disc_year', 'disc_telescope', 'discoverymethod', 'releasedate'])

# %%
list7[0].values()
# Out:
# dict_values(['OGLE-TR-10 b', 'OGLE-TR-10', 'b', 197.046, 0.62, 14.011, 1.25, 3.101278, 0.4, None, None, 1, 1, 0, 1.14, 0.188, None, None, 1344.97, 2004, '1.3 m Warsaw University Telescope', 'Transit', '2014-05-14'])

# %%
(list7[0]).items()
# Out:
# dict_items([('pl_name', 'OGLE-TR-10 b'), ('hostname', 'OGLE-TR-10'), ('pl_letter', 'b'), ('pl_bmasse', 197.046), ('pl_bmassj', 0.62), ('pl_rade', 14.011), ('pl_radj', 1.25), ('pl_orbper', 3.101278), ('pl_dens', 0.4), ('pl_trandur', None), ('pl_ratror', None), ('sy_snum', 1), ('sy_pnum', 1), ('sy_mnum', 0), ('st_mass', 1.14), ('st_lum', 0.188), ('st_age', None), ('st_dens', None), ('sy_dist', 1344.97), ('disc_year', 2004), ('disc_telescope', '1.3 m Warsaw University Telescope'), ('discoverymethod', 'Transit'), ('releasedate', '2014-05-14')])

# %%
list_of_dict = [
    {"course": "DBMS", "price": 1500},
    {"course": "Python", "price": 2500},
    {"course": "Java", "price": 2500},
]
dict_7_0 = list7[0]
dict_7_0
# Out:
# {'pl_name': 'OGLE-TR-10 b',
#  'hostname': 'OGLE-TR-10',
#  'pl_letter': 'b',
#  'pl_bmasse': 197.046,
#  'pl_bmassj': 0.62,
#  'pl_rade': 14.011,
#  'pl_radj': 1.25,
#  'pl_orbper': 3.101278,
#  'pl_dens': 0.4,
#  'pl_trandur': None,
#  'pl_ratror': None,
#  'sy_snum': 1,
#  'sy_pnum': 1,
#  'sy_mnum': 0,
#  'st_mass': 1.14,
#  'st_lum': 0.188,
#  'st_age': None,
#  'st_dens': None,
#  'sy_dist': 1344.97,
#  'disc_year': 2004,
#  'disc_telescope': '1.3 m Warsaw University Telescope',
#  'discoverymethod': 'Transit',
#  'releasedate': '2014-05-14'}

# %%
dict_7_0['pl_name']
# Out:
# 'OGLE-TR-10 b'

# %%
#nombre de planete par distance
y10=y20=y30=y40=y50=y60=y70=y80=y90=y100=0
for planete in list7:
    #print(planete['pl_name'])
    if planete['sy_dist'] is None: 
        pass
    else:
        if planete['sy_dist'] < 10.00:
            #print(planete['pl_name'])
            y10+=1
        elif planete['sy_dist'] >= 10.00 and planete['sy_dist'] < 20.00:
            #print(planete['pl_name'])
            y20+=1
        elif (planete['sy_dist'] >= 20.00) and (planete['sy_dist']) < 30.00:
            #print(planete['pl_name'])
            y30+=1
        elif (planete['sy_dist'] >= 30.00) and (planete['sy_dist']) < 40.00:
            #print(planete['pl_name'])
            y30+=1
        elif (planete['sy_dist'] >= 40.00) and (planete['sy_dist']) < 50.00:
            #print(planete['pl_name'])
            y40+=1
        elif (planete['sy_dist'] >= 50.00) and (planete['sy_dist']) < 60.00:
            #print(planete['pl_name'])
            y50+=1
        elif (planete['sy_dist'] >= 60.00) and (planete['sy_dist']) < 70.00:
            #print(planete['pl_name'])
            y60+=1
        elif (planete['sy_dist'] >= 70.00) and (planete['sy_dist']) < 80.00:
            #print(planete['pl_name'])
            y70+=1
        elif (planete['sy_dist'] >= 80.00) and (planete['sy_dist']) < 90.00:
            #print(planete['pl_name'])
            y80+=1
        elif (planete['sy_dist'] >= 90.00) and (planete['sy_dist']) < 100.00:
            #print(planete['pl_name'])
            y90+=1
        
        else:
            y100+=1
            
print(y10)
print(y20)
print(y30)
print(y40)
print(y50)
print(y60)
print(y70)
print(y80)
print(y90)
print(y100)
# Out:
# 107
# 171
# 389
# 182
# 146
# 137
# 93
# 77
# 63
# 4300

# %%
#nombre de planete par année
y0=y1=y2=y3=y4=y5=y6=y7=y8=y9=0
now = datetime.date.today()
y0 = now.year
for planete in list7:
    #print(planete['pl_name'])
    if planete['disc_year'] is None: 
        pass
    else:
        if planete['disc_year'] == y0 :
            #print(planete['pl_name'])
            y1+=1
        elif planete['disc_year'] == y0  -1 :
            #print(planete['pl_name'])
            y2+=1
        elif planete['disc_year'] == y0 - 2 :
            #print(planete['pl_name'])
            y3+=1
        elif planete['disc_year'] == y0 - 3 :
            #print(planete['pl_name'])
            y4+=1
        elif planete['disc_year'] == y0 - 4 :
            #print(planete['pl_name'])
            y5+=1
        elif planete['disc_year'] == y0 - 5 :
            #print(planete['pl_name'])
            y6+=1
        elif planete['disc_year'] == y0 - 6 :
            #print(planete['pl_name'])
            y7+=1
        elif planete['disc_year'] == y0 - 7 :
            #print(planete['pl_name'])
            y8+=1
        elif planete['disc_year'] == y0 - 8 :
            #print(planete['pl_name'])
            y9+=1
        else:
            y10+=1
            
print(y1)
print(y2)
print(y3)
print(y4)
print(y5)
print(y6)
print(y7)
print(y8)
print(y9)
print(y10)
# Out:
# 213
# 324
# 364
# 523
# 233
# 202
# 323
# 154
# 1511
# 2048

# %%
list7[0]
# Out:
# {'pl_name': 'OGLE-TR-10 b',
#  'hostname': 'OGLE-TR-10',
#  'pl_letter': 'b',
#  'pl_bmasse': 197.046,
#  'pl_bmassj': 0.62,
#  'pl_rade': 14.011,
#  'pl_radj': 1.25,
#  'pl_orbper': 3.101278,
#  'pl_dens': 0.4,
#  'pl_trandur': None,
#  'pl_ratror': None,
#  'sy_snum': 1,
#  'sy_pnum': 1,
#  'sy_mnum': 0,
#  'st_mass': 1.14,
#  'st_lum': 0.188,
#  'st_age': None,
#  'st_dens': None,
#  'sy_dist': 1344.97,
#  'disc_year': 2004,
#  'disc_telescope': '1.3 m Warsaw University Telescope',
#  'discoverymethod': 'Transit',
#  'releasedate': '2014-05-14'}

# %%
dist0 = 100000
p1 ="vide"
p=0
planete_dist=[]
for planete in list7:
    if planete['sy_dist'] is None: 
        pass
    else:
        p+=1
        planete_dist.append((planete['pl_name'],planete['sy_dist'],planete['pl_bmasse'], planete['pl_rade'], planete['pl_dens']))
        if planete['sy_dist'] < dist0:
           p1 = planete['pl_name']
           dist0 =  planete['sy_dist']
        

#print(p, p1, dist0)
#print(planete_dist)

# %%
type(list7)
# Out:
# list

# %%
planete_dist[0]
# Out:
# ('OGLE-TR-10 b', 1344.97, 197.046, 14.011, 0.4)

# %%
planete_dist
# Out:
# [('OGLE-TR-10 b', 1344.97, 197.046, 14.011, 0.4),
#  ('BD-08 2823 c', 41.3342, 104.0, None, None),
#  ('HD 110014 b', 100.758, 3524.59, None, None),
#  ('GJ 667 C f', 7.24396, 2.7, None, None),
#  ('GJ 667 C g', 7.24396, 4.6, None, None),
#  ('GJ 667 C c', 7.24396, 3.8, None, None),
#  ('Kepler-131 b', 228.678, 16.13, 2.41, 6.0),
#  ('KELT-7 b', 136.681, 441.7837, 17.934, None),
#  ('HATS-61 b', 679.761, 1080.622, 13.395, 2.47),
#  ('HATS-63 b', 623.232, 305.1168, 13.529, 0.67),
#  ('HD 108236 c', 64.5978, None, 2.071, None),
#  ('TOI-1224 b', 37.3312, None, 2.104, None),
#  ('TOI-1224 c', 37.3312, None, 2.884, None),
#  ('HD 48948 b', 16.9043, 4.88, None, None),
#  ('HD 48948 c', 16.9043, 7.27, None, None),
#  ('HD 48948 d', 16.9043, 10.59, None, None),
#  ('WASP-76 b', 194.459, 284.1386, 20.781, 0.17),
#  ('OGLE-2014-BLG-0221L b', 3680.0, 1382.55357, None, None),
#  ('PDS 70 b', 113.064, 953.49, 30.488, None),
#  ('bet Pic b', 19.7442, 3727.80939, None, None),
# ...

# %%
ListePrincipale = sorted(planete_dist, reverse=False)
#ListePrincipale

# %%
ListePrincipale[:10]
# Out:
# [('11 Com b', 93.1846, 4914.89849, None, None),
#  ('11 UMi b', 125.321, 4684.8142, None, None),
#  ('14 And b', 75.4392, 1131.1513, None, None),
#  ('14 Her b', 17.9323, 2559.47216, None, None),
#  ('16 Cyg B b', 21.1397, 565.7374, None, None),
#  ('17 Sco b', 124.953, 1373.01872, None, None),
#  ('18 Del b', 76.222, 2926.24614, None, None),
#  ('1RXS J160929.1-210524 b', 139.135, 3000.0, None, None),
#  ('24 Boo b', 95.9863, 280.64248, None, None),
#  ('24 Sex b', 72.0691, 632.46, None, None)]

# %%
sorted_list = sorted(planete_dist, key= lambda x: x[1])
sorted_list[:3]
# Out:
# [('Proxima Cen b', 1.30119, 1.07, None, None),
#  ('Barnard b', 1.82655, 0.37, None, None),
#  ('eps Eri b', 3.2026, 209.76675, None, None)]

# %%
sorted_list
# Out:
# [('Proxima Cen b', 1.30119, 1.07, None, None),
#  ('Barnard b', 1.82655, 0.37, None, None),
#  ('eps Eri b', 3.2026, 209.76675, None, None),
#  ('GJ 887 c', 3.29, 7.6, None, None),
#  ('GJ 887 b', 3.29, 4.2, None, None),
#  ('Ross 128 b', 3.37454, 1.4, None, None),
#  ('GJ 15 A b', 3.56228, 3.03, None, None),
#  ('GJ 15 A c', 3.56228, 36.0, None, None),
#  ('tau Cet g', 3.60304, 1.75, None, None),
#  ('tau Cet h', 3.60304, 1.83, None, None),
#  ('tau Cet e', 3.60304, 3.93, None, None),
#  ('tau Cet f', 3.60304, 3.93, None, None),
#  ('eps Ind A b', 3.63857, 2005.49725, None, None),
#  ('GJ 1061 b', 3.67278, 1.37, None, None),
#  ('GJ 1061 d', 3.67278, 1.64, None, None),
#  ('GJ 1061 c', 3.67278, 1.74, None, None),
#  ('YZ Cet c', 3.71207, 1.14, None, None),
#  ('YZ Cet b', 3.71207, 0.7, None, None),
#  ('YZ Cet d', 3.71207, 1.09, None, None),
#  ("Teegarden's Star b", 3.83078, 1.16, None, None),
#  ("Teegarden's Star c", 3.83078, 1.05, None, None),
# ...

# %%
extrait1 = [(t[1],t[2]) for t in sorted_list]

# %%
extrait1
# Out:
# [(1.30119, 1.07),
#  (1.82655, 0.37),
#  (3.2026, 209.76675),
#  (3.29, 7.6),
#  (3.29, 4.2),
#  (3.37454, 1.4),
#  (3.56228, 3.03),
#  (3.56228, 36.0),
#  (3.60304, 1.75),
#  (3.60304, 1.83),
#  (3.60304, 3.93),
#  (3.60304, 3.93),
#  (3.63857, 2005.49725),
#  (3.67278, 1.37),
#  (3.67278, 1.64),
#  (3.67278, 1.74),
#  (3.71207, 1.14),
#  (3.71207, 0.7),
#  (3.71207, 1.09),
#  (3.83078, 1.16),
#  (3.83078, 1.05),
#  (3.83078, 0.82),
#  (3.93305, 7.0),
#  (4.30592, 3.41),
#  (4.30592, 7.7),
#  (4.30592, 1.91),
#  (4.471, 66.74397),
#  (4.54896, 11.09),
#  (4.54939, 16.0),
#  (4.54939, 17.2),
#  (4.67517, 723.2235),
#  (4.67517, 226.9846),
#  (4.67517, 6.83),
#  (4.67517, 14.6),
#  (4.84867, 1.08),
#  (4.84867, 1.36),
#  (4.96435, 314.65012),
#  (5.00671, 4.4),
#  (5.00671, 8.7),
#  (5.37484, 2.31),
#  (5.37484, 2.02),
#  (5.58057, 4.0),
#  (5.675773, 13.6),
#  (5.675773, 2.69),
#  (5.75624, 8.58137),
#  (5.75624, 14.93794),
#  (5.91059, 12.214),
#  (5.921535, 1.18),
# ...

# %%
masse_rayon1 = [(t[2],t[3]) for t in sorted_list if t[2] is not None and t[3] is not None]

# %%
masse_rayon1
# Out:
# [(7.3, 1.31),
#  (4.74, 1.602),
#  (16.17, 1.61),
#  (4.36, 1.511),
#  (1.54, 1.147),
#  (2.77, 1.289),
#  (0.633, 0.699),
#  (22.1, 4.17),
#  (2.14, 1.24),
#  (3.09, 1.533),
#  (2.22, 1.385),
#  (1.94, 1.521),
#  (0.4, 0.85),
#  (2542.62726, 12.442),
#  (1906.98, 14.011),
#  (53.83, 8.4),
#  (7.6, 2.63),
#  (1.9, 1.331),
#  (3.87, 0.958),
#  (7.99, 1.875),
#  (1.83705, 1.192),
#  (8.41, 2.733),
#  (4.72, 1.664),
#  (11.24, 2.916),
#  (8.82, 2.562),
#  (5.6, 1.73),
#  (1.91, 1.272),
#  (1.75, 1.09),
#  (22.7, 2.61),
#  (3.7, 0.892),
#  (6991.57, 11.777),
#  (2.33, 1.242),
#  (359.1479, 12.666),
#  (4.23, 1.71),
#  (1.44, 1.079),
#  (1.32, 1.193),
#  (8.3, 2.12),
#  (7.5, 1.015),
#  (2.46, 1.325),
#  (8.04, 2.39),
#  (2.68, 1.52),
#  (37.3, 2.164),
#  (17.2, 2.582),
#  (1.258, 1.13),
#  (3.34, 2.13),
#  (4.78, 2.133),
#  (6.15, 2.355),
#  (1.58, 1.206),
#  (41.89, 7.27),
#  (9.13, 2.69),
#  (4.0, 1.03),
#  (6.1, 2.25),
#  (4386.054, 10.4),
#  (6.64, 2.064),
#  (3.21, 1.28),
# ...

# %%
sorted_list[0][1]
# Out:
# 1.30119

# %%
#print(list7)
#tri par pl_name

# %%
planete_name_list = sorted(list7, key= lambda x: x['pl_name'])
planete_name_list[0]
# Out:
# {'pl_name': '11 Com b',
#  'hostname': '11 Com',
#  'pl_letter': 'b',
#  'pl_bmasse': 4914.89849,
#  'pl_bmassj': 15.464,
#  'pl_rade': None,
#  'pl_radj': None,
#  'pl_orbper': 323.21,
#  'pl_dens': None,
#  'pl_trandur': None,
#  'pl_ratror': None,
#  'sy_snum': 2,
#  'sy_pnum': 1,
#  'sy_mnum': 0,
#  'st_mass': 2.09,
#  'st_lum': 1.978,
#  'st_age': None,
#  'st_dens': None,
#  'sy_dist': 93.1846,
#  'disc_year': 2007,
#  'disc_telescope': '2.16 m Telescope',
#  'discoverymethod': 'Radial Velocity',
#  'releasedate': '2023-09-19'}

# %%
from operator import is_not
from functools import partial
planete_dist_list0=list(filter(partial(is_not, None), planete_name_list))
keyValList =[None]
exampleSet = planete_dist_list0

# %%
planete_dist_list =list(filter(lambda d: d['sy_dist'] not in keyValList, exampleSet))

# %%
planete_dist_list1 = sorted(planete_dist_list, key= lambda x: x['sy_dist'])

# %%
len(planete_dist_list1[:5])
# Out:
# 5

# %%
planete_dist_list1[:2][1]['sy_dist']
# Out:
# 1.82655

# %%
planete_dist_list1[:2][1]['pl_name']
# Out:
# 'Barnard b'

# %%
len(planete_name_list )
# Out:
# 5788

# %%
len([i for i in planete_name_list if i['discoverymethod'] == 'Radial Velocity'])
# Out:
# 1094

# %%
discoverymethod_counts = {}
for track in planete_name_list:
    method = track.get('discoverymethod')
    try:
        discoverymethod_counts[method] += 1
    except KeyError:
        discoverymethod_counts[method] = 1

# %%
discoverymethod_counts
# Out:
# {'Radial Velocity': 1094,
#  'Imaging': 82,
#  'Eclipse Timing Variations': 17,
#  'Transit': 4310,
#  'Transit Timing Variations': 32,
#  'Astrometry': 3,
#  'Microlensing': 230,
#  'Disk Kinematics': 1,
#  'Orbital Brightness Modulation': 9,
#  'Pulsation Timing Variations': 2,
#  'Pulsar Timing': 8}

# %%
ordered_discoverymethod_counts = dict(sorted(discoverymethod_counts.items()))

# %%
ordered_discoverymethod_counts
# Out:
# {'Astrometry': 3,
#  'Disk Kinematics': 1,
#  'Eclipse Timing Variations': 17,
#  'Imaging': 82,
#  'Microlensing': 230,
#  'Orbital Brightness Modulation': 9,
#  'Pulsar Timing': 8,
#  'Pulsation Timing Variations': 2,
#  'Radial Velocity': 1094,
#  'Transit': 4310,
#  'Transit Timing Variations': 32}

# %%
v =sorted(discoverymethod_counts.items(), key=lambda x: x[1], reverse=True)

# %%
v
# Out:
# [('Transit', 4310),
#  ('Radial Velocity', 1094),
#  ('Microlensing', 230),
#  ('Imaging', 82),
#  ('Transit Timing Variations', 32),
#  ('Eclipse Timing Variations', 17),
#  ('Orbital Brightness Modulation', 9),
#  ('Pulsar Timing', 8),
#  ('Astrometry', 3),
#  ('Pulsation Timing Variations', 2),
#  ('Disk Kinematics', 1)]

# %%
v[0][0]
v[0][1]
# Out:
# 4310

# %%
somme_m = sum(ordered_discoverymethod_counts.values())
somme_m
# Out:
# 5788

# %%
float((v[0][1] / somme_m)*100)
# Out:
# 74.46440912232205

# %%
len(planete_name_list)
# Out:
# 5788

# %%
planete_name_list[:5]
# Out:
# [{'pl_name': '11 Com b',
#   'hostname': '11 Com',
#   'pl_letter': 'b',
#   'pl_bmasse': 4914.89849,
#   'pl_bmassj': 15.464,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 323.21,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 2,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 2.09,
#   'st_lum': 1.978,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 93.1846,
#   'disc_year': 2007,
#   'disc_telescope': '2.16 m Telescope',
#   'discoverymethod': 'Radial Velocity',
#   'releasedate': '2023-09-19'},
#  {'pl_name': '11 UMi b',
#   'hostname': '11 UMi',
#   'pl_letter': 'b',
#   'pl_bmasse': 4684.8142,
#   'pl_bmassj': 14.74,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 516.21997,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 2.78,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 125.321,
# ...

# %%
print(list7[0])
# Out:
# {'pl_name': 'OGLE-TR-10 b', 'hostname': 'OGLE-TR-10', 'pl_letter': 'b', 'pl_bmasse': 197.046, 'pl_bmassj': 0.62, 'pl_rade': 14.011, 'pl_radj': 1.25, 'pl_orbper': 3.101278, 'pl_dens': 0.4, 'pl_trandur': None, 'pl_ratror': None, 'sy_snum': 1, 'sy_pnum': 1, 'sy_mnum': 0, 'st_mass': 1.14, 'st_lum': 0.188, 'st_age': None, 'st_dens': None, 'sy_dist': 1344.97, 'disc_year': 2004, 'disc_telescope': '1.3 m Warsaw University Telescope', 'discoverymethod': 'Transit', 'releasedate': '2014-05-14'}

# %%
urlexo8 = "https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+\
pl_name,hostname,pl_letter,pl_bmasse,pl_bmassj,pl_rade,pl_radj,pl_orbper,pl_dens,pl_trandur,pl_ratror,\
sy_snum,sy_pnum,sy_mnum,st_mass,st_lum,st_age,st_dens,sy_dist,disc_year,disc_telescope,discoverymethod,releasedate\
+from+ps+where+default_flag=1&format=json"

print(urlexo8)
list8 = json.loads(urlopen(urlexo8).read().decode("utf-8"))
# Out:
# https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+pl_name,hostname,pl_letter,pl_bmasse,pl_bmassj,pl_rade,pl_radj,pl_orbper,pl_dens,pl_trandur,pl_ratror,sy_snum,sy_pnum,sy_mnum,st_mass,st_lum,st_age,st_dens,sy_dist,disc_year,disc_telescope,discoverymethod,releasedate+from+ps+where+default_flag=1&format=json

# %%
print(list8[0])
# Out:
# {'pl_name': 'OGLE-TR-10 b', 'hostname': 'OGLE-TR-10', 'pl_letter': 'b', 'pl_bmasse': 197.046, 'pl_bmassj': 0.62, 'pl_rade': 14.011, 'pl_radj': 1.25, 'pl_orbper': 3.101278, 'pl_dens': 0.4, 'pl_trandur': None, 'pl_ratror': None, 'sy_snum': 1, 'sy_pnum': 1, 'sy_mnum': 0, 'st_mass': 1.14, 'st_lum': 0.188, 'st_age': None, 'st_dens': None, 'sy_dist': 1344.97, 'disc_year': 2004, 'disc_telescope': '1.3 m Warsaw University Telescope', 'discoverymethod': 'Transit', 'releasedate': '2014-05-14'}

# %%
import pandas as pd
df8 = pd.DataFrame(list8)

# %%
print(df8)
# Out:
#            pl_name    hostname pl_letter  pl_bmasse  pl_bmassj  pl_rade  \
# 0     OGLE-TR-10 b  OGLE-TR-10         b    197.046    0.62000   14.011
# 1     BD-08 2823 c  BD-08 2823         c    104.000    0.33000      NaN
# 2      HD 110014 b   HD 110014         b   3524.590   11.09000      NaN
# 3       GJ 667 C f    GJ 667 C         f      2.700    0.00800      NaN
# 4       GJ 667 C g    GJ 667 C         g      4.600    0.01400      NaN
# ...            ...         ...       ...        ...        ...      ...
# 5783  Kepler-586 b  Kepler-586         b        NaN        NaN    2.790
# 5784  Kepler-169 c  Kepler-169         c        NaN        NaN    1.210
# 5785  Kepler-592 b  Kepler-592         b        NaN        NaN    2.390
# 5786      55 Cnc b      55 Cnc         b    255.400    0.80360      NaN
# 5787      55 Cnc e      55 Cnc         e      7.990    0.02514    1.875
#
#       pl_radj   pl_orbper  pl_dens  pl_trandur  ...  sy_mnum  st_mass  st_lum  \
# ...

# %%
df9 = df8[(df8['pl_name']=='GJ 9827 d')]

# %%
df9
# Out:
#        pl_name hostname pl_letter  pl_bmasse  pl_bmassj  pl_rade  pl_radj  \
# 655  GJ 9827 d  GJ 9827         d       3.02     0.0095     1.98    0.177
#
#      pl_orbper  pl_dens  pl_trandur  ...  sy_mnum  st_mass  st_lum  st_age  \
# 655    6.20183      NaN         NaN  ...        0     0.62  -1.004   5.465
#
#      st_dens  sy_dist  disc_year           disc_telescope  discoverymethod  \
# 655      NaN   29.661       2017  0.95 m Kepler Telescope          Transit
#
#      releasedate
# 655   2024-10-15
#
# [1 rows x 23 columns]

# %%
df9
# Out:
#        pl_name hostname pl_letter  pl_bmasse  pl_bmassj  pl_rade  pl_radj  \
# 655  GJ 9827 d  GJ 9827         d       3.02     0.0095     1.98    0.177
#
#      pl_orbper  pl_dens  pl_trandur  ...  sy_mnum  st_mass  st_lum  st_age  \
# 655    6.20183      NaN         NaN  ...        0     0.62  -1.004   5.465
#
#      st_dens  sy_dist  disc_year           disc_telescope  discoverymethod  \
# 655      NaN   29.661       2017  0.95 m Kepler Telescope          Transit
#
#      releasedate
# 655   2024-10-15
#
# [1 rows x 23 columns]

# %%
df8
# Out:
#            pl_name    hostname pl_letter  pl_bmasse  pl_bmassj  pl_rade  \
# 0     OGLE-TR-10 b  OGLE-TR-10         b    197.046    0.62000   14.011
# 1     BD-08 2823 c  BD-08 2823         c    104.000    0.33000      NaN
# 2      HD 110014 b   HD 110014         b   3524.590   11.09000      NaN
# 3       GJ 667 C f    GJ 667 C         f      2.700    0.00800      NaN
# 4       GJ 667 C g    GJ 667 C         g      4.600    0.01400      NaN
# ...            ...         ...       ...        ...        ...      ...
# 5783  Kepler-586 b  Kepler-586         b        NaN        NaN    2.790
# 5784  Kepler-169 c  Kepler-169         c        NaN        NaN    1.210
# 5785  Kepler-592 b  Kepler-592         b        NaN        NaN    2.390
# 5786      55 Cnc b      55 Cnc         b    255.400    0.80360      NaN
# 5787      55 Cnc e      55 Cnc         e      7.990    0.02514    1.875
#
#       pl_radj   pl_orbper  pl_dens  pl_trandur  ...  sy_mnum  st_mass  st_lum  \
# ...

# %%
print(df8['releasedate'].str.contains('2024'))
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5783    False
# 5784    False
# 5785    False
# 5786    False
# 5787    False
# Name: releasedate, Length: 5788, dtype: bool

# %%
print(df8[df8['releasedate'].str.contains('2024')])
# Out:
#                pl_name       hostname pl_letter   pl_bmasse  pl_bmassj  \
# 8            HATS-61 b        HATS-61         b  1080.62200    3.40000
# 9            HATS-63 b        HATS-63         b   305.11680    0.96000
# 11          TOI-1224 b       TOI-1224         b         NaN        NaN
# 12          TOI-1224 c       TOI-1224         c         NaN        NaN
# 13          HD 48948 b       HD 48948         b     4.88000    0.01535
# ...                ...            ...       ...         ...        ...
# 5451  Kepler-1660 AB b  Kepler-1660 A         b  1586.59941    4.99200
# 5464     Kepler-1489 c    Kepler-1489         c         NaN        NaN
# 5473      Kepler-128 b     Kepler-128         b     3.79000    0.01192
# 5538       Kepler-23 b      Kepler-23         b     2.56000    0.00805
# 5764       Kepler-23 d      Kepler-23         d     4.44000    0.01397
#
#       pl_rade  pl_radj   pl_orbper  pl_dens  pl_trandur  ...  sy_mnum  \
# ...

# %%
df8byd= df8[df8['releasedate'].str.contains('2024')]
df8byd
# Out:
#                pl_name       hostname pl_letter   pl_bmasse  pl_bmassj  \
# 8            HATS-61 b        HATS-61         b  1080.62200    3.40000
# 9            HATS-63 b        HATS-63         b   305.11680    0.96000
# 11          TOI-1224 b       TOI-1224         b         NaN        NaN
# 12          TOI-1224 c       TOI-1224         c         NaN        NaN
# 13          HD 48948 b       HD 48948         b     4.88000    0.01535
# ...                ...            ...       ...         ...        ...
# 5451  Kepler-1660 AB b  Kepler-1660 A         b  1586.59941    4.99200
# 5464     Kepler-1489 c    Kepler-1489         c         NaN        NaN
# 5473      Kepler-128 b     Kepler-128         b     3.79000    0.01192
# 5538       Kepler-23 b      Kepler-23         b     2.56000    0.00805
# 5764       Kepler-23 d      Kepler-23         d     4.44000    0.01397
#
#       pl_rade  pl_radj   pl_orbper  pl_dens  pl_trandur  ...  sy_mnum  \
# ...

# %%
df8_sortbyd= df8.sort_values(by=['releasedate'], ascending=False)
df8_sortbyd[:10]
# Out:
#       pl_name hostname pl_letter  pl_bmasse  pl_bmassj  pl_rade  pl_radj  \
# 311   K2-54 b    K2-54         b        NaN        NaN    2.612    0.233
# 331  K2-260 b   K2-260         b  546.66486     1.7200   18.416    1.643
# 313  K2-180 b   K2-180         b   11.41004     0.0359    2.466    0.220
# 314   K2-97 b    K2-97         b  174.48780     0.5490   13.451    1.200
# 315  K2-181 b   K2-181         b        NaN        NaN    2.836    0.253
# 316  K2-182 b   K2-182         b   20.97667     0.0660    2.713    0.242
# 317   K2-98 b    K2-98         b   34.00764     0.1070    5.066    0.452
# 318  K2-114 b   K2-114         b  638.83510     2.0100   10.592    0.945
# 319  K2-115 b   K2-115         b  321.00669     1.0100   11.803    1.053
# 320  K2-277 b   K2-277         b        NaN        NaN    2.186    0.195
#
#      pl_orbper  pl_dens  pl_trandur  ...  sy_mnum  st_mass  st_lum  st_age  \
# 311   9.783300      NaN     2.78880  ...        0     0.61  -1.022     NaN
# ...

# %%
df8_sortbyd
# Out:
#            pl_name    hostname pl_letter  pl_bmasse  pl_bmassj  pl_rade  \
# 311        K2-54 b       K2-54         b        NaN        NaN    2.612
# 331       K2-260 b      K2-260         b  546.66486     1.7200   18.416
# 313       K2-180 b      K2-180         b   11.41004     0.0359    2.466
# 314        K2-97 b       K2-97         b  174.48780     0.5490   13.451
# 315       K2-181 b      K2-181         b        NaN        NaN    2.836
# ...            ...         ...       ...        ...        ...      ...
# 4377  Kepler-181 c  Kepler-181         c        NaN        NaN    1.990
# 4374  Kepler-276 c  Kepler-276         c   16.60000     0.0520    2.900
# 4373  Kepler-240 c  Kepler-240         c        NaN        NaN    2.200
# 439   Kepler-164 d  Kepler-164         d        NaN        NaN    2.450
# 0     OGLE-TR-10 b  OGLE-TR-10         b  197.04600     0.6200   14.011
#
#       pl_radj  pl_orbper  pl_dens  pl_trandur  ...  sy_mnum  st_mass  st_lum  \
# ...

# %%
df8_sortbyd[:20]
# Out:
#       pl_name hostname pl_letter  pl_bmasse  pl_bmassj  pl_rade  pl_radj  \
# 311   K2-54 b    K2-54         b        NaN        NaN    2.612    0.233
# 331  K2-260 b   K2-260         b  546.66486     1.7200   18.416    1.643
# 313  K2-180 b   K2-180         b   11.41004     0.0359    2.466    0.220
# 314   K2-97 b    K2-97         b  174.48780     0.5490   13.451    1.200
# 315  K2-181 b   K2-181         b        NaN        NaN    2.836    0.253
# 316  K2-182 b   K2-182         b   20.97667     0.0660    2.713    0.242
# 317   K2-98 b    K2-98         b   34.00764     0.1070    5.066    0.452
# 318  K2-114 b   K2-114         b  638.83510     2.0100   10.592    0.945
# 319  K2-115 b   K2-115         b  321.00669     1.0100   11.803    1.053
# 320  K2-277 b   K2-277         b        NaN        NaN    2.186    0.195
# 321  K2-203 b   K2-203         b        NaN        NaN    1.265    0.113
# 322  K2-204 b   K2-204         b        NaN        NaN    3.172    0.283
# ...

# %%
urlexo9 = "https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+\
pl_name,hostname,pl_letter,pl_bmasse,pl_bmassj,pl_rade,pl_radj,pl_orbper,pl_dens,pl_trandur,pl_ratror,\
sy_snum,sy_pnum,sy_mnum,st_mass,st_lum,st_age,st_dens,sy_dist,disc_year,disc_telescope,discoverymethod,\
releasedate\
+from+ps+where+releasedate='2024-10-22'&format=json"

# %%
print(urlexo9)
list9 = json.loads(urlopen(urlexo9).read().decode("utf-8"))
print(list9)
# Out:
# https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+pl_name,hostname,pl_letter,pl_bmasse,pl_bmassj,pl_rade,pl_radj,pl_orbper,pl_dens,pl_trandur,pl_ratror,sy_snum,sy_pnum,sy_mnum,st_mass,st_lum,st_age,st_dens,sy_dist,disc_year,disc_telescope,discoverymethod,releasedate+from+ps+where+releasedate='2024-10-22'&format=json
# ...

# %%
import pandas as pd
df9 = pd.DataFrame(list9)

# %%
df9
# Out:
#             pl_name          hostname pl_letter  pl_bmasse  pl_bmassj  \
# 0       Kepler-51 b         Kepler-51         b    3.50000    0.01101
# 1       Kepler-51 b         Kepler-51         b    6.70000    0.02108
# 2       Kepler-51 d         Kepler-51         d    5.60000    0.01762
# 3       Kepler-51 d         Kepler-51         d    6.60000    0.02077
# 4       Kepler-51 c         Kepler-51         c    6.09000    0.01916
# 5       Kepler-51 c         Kepler-51         c    5.65000    0.01778
# 6          G 9-40 b            G 9-40         b    4.00000    0.01259
# 7         NGTS-11 b           NGTS-11         b        NaN        NaN
# 8   TIC 172900988 b  TIC 172900988 Aa         b  603.87397    1.90000
# 9        TOI-4438 b          TOI-4438         b        NaN        NaN
# 10  TIC 393818343 b     TIC 393818343         b        NaN        NaN
# 11       TOI-5005 b          TOI-5005         b   32.70000    0.10300
# ...

# %%
df9_sortbyd= df9.sort_values(by=['releasedate'], ascending=False)
df9_sortbyd[:20]
# Out:
#             pl_name          hostname pl_letter  pl_bmasse  pl_bmassj  \
# 0       Kepler-51 b         Kepler-51         b    3.50000    0.01101
# 10  TIC 393818343 b     TIC 393818343         b        NaN        NaN
# 17       TOI-5319 b          TOI-5319         b        NaN        NaN
# 16       TOI-2768 b          TOI-2768         b        NaN        NaN
# 15       TOI-2274 b          TOI-2274         b        NaN        NaN
# 14       TOI-1883 b          TOI-1883         b        NaN        NaN
# 13      Kepler-51 e         Kepler-51         e    5.40000    0.01699
# 12      Kepler-51 e         Kepler-51         e    3.80000    0.01196
# 11       TOI-5005 b          TOI-5005         b   32.70000    0.10300
# 9        TOI-4438 b          TOI-4438         b        NaN        NaN
# 1       Kepler-51 b         Kepler-51         b    6.70000    0.02108
# 8   TIC 172900988 b  TIC 172900988 Aa         b  603.87397    1.90000
# ...

# %%
df9_ten=df9[df9['releasedate']>='2024-10-20']

# %%
df9_ten
# Out:
#             pl_name          hostname pl_letter  pl_bmasse  pl_bmassj  \
# 0       Kepler-51 b         Kepler-51         b    3.50000    0.01101
# 1       Kepler-51 b         Kepler-51         b    6.70000    0.02108
# 2       Kepler-51 d         Kepler-51         d    5.60000    0.01762
# 3       Kepler-51 d         Kepler-51         d    6.60000    0.02077
# 4       Kepler-51 c         Kepler-51         c    6.09000    0.01916
# 5       Kepler-51 c         Kepler-51         c    5.65000    0.01778
# 6          G 9-40 b            G 9-40         b    4.00000    0.01259
# 7         NGTS-11 b           NGTS-11         b        NaN        NaN
# 8   TIC 172900988 b  TIC 172900988 Aa         b  603.87397    1.90000
# 9        TOI-4438 b          TOI-4438         b        NaN        NaN
# 10  TIC 393818343 b     TIC 393818343         b        NaN        NaN
# 11       TOI-5005 b          TOI-5005         b   32.70000    0.10300
# ...

# %%
print(list9)
# Out:
# [{'pl_name': 'Kepler-51 b', 'hostname': 'Kepler-51', 'pl_letter': 'b', 'pl_bmasse': 3.5, 'pl_bmassj': 0.01101, 'pl_rade': 6.83, 'pl_radj': 0.609, 'pl_orbper': 45.15405, 'pl_dens': 0.06, 'pl_trandur': 5.754, 'pl_ratror': 0.07225, 'sy_snum': 1, 'sy_pnum': 4, 'sy_mnum': 0, 'st_mass': 0.96, 'st_lum': None, 'st_age': 0.7, 'st_dens': 2.0865, 'sy_dist': 783.831, 'disc_year': 2012, 'disc_telescope': '0.95 m Kepler Telescope', 'discoverymethod': 'Transit', 'releasedate': '2024-10-22'}, {'pl_name': 'Kepler-51 b', 'hostname': 'Kepler-51', 'pl_letter': 'b', 'pl_bmasse': 6.7, 'pl_bmassj': 0.02108, 'pl_rade': 6.83, 'pl_radj': 0.609, 'pl_orbper': 45.15396, 'pl_dens': 0.115, 'pl_trandur': 5.754, 'pl_ratror': 0.07225, 'sy_snum': 1, 'sy_pnum': 4, 'sy_mnum': 0, 'st_mass': 0.96, 'st_lum': None, 'st_age': 0.7, 'st_dens': 2.0865, 'sy_dist': 783.831, 'disc_year': 2012, 'disc_telescope': '0.95 m Kepler Telescope', 'discoverymethod': 'Transit', 'releasedate': '2024-10-22'}, {'pl_name': 'Kepler-51 d', 'hostna
# ...

# %%
urlexo9a = "https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+\
pl_name,hostname,pl_letter,pl_bmasse,pl_bmassj,pl_rade,pl_radj,pl_orbper,pl_dens,pl_trandur,pl_ratror,\
sy_snum,sy_pnum,sy_mnum,st_mass,st_lum,st_age,st_dens,sy_dist,disc_year,disc_telescope,discoverymethod,\
releasedate\
+from+ps+order+by+releasedate+desc+&format=json"

# %%
print(urlexo9a)
list9a = json.loads(urlopen(urlexo9a).read().decode("utf-8"))
print(list9a[:10])
# Out:
# https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+pl_name,hostname,pl_letter,pl_bmasse,pl_bmassj,pl_rade,pl_radj,pl_orbper,pl_dens,pl_trandur,pl_ratror,sy_snum,sy_pnum,sy_mnum,st_mass,st_lum,st_age,st_dens,sy_dist,disc_year,disc_telescope,discoverymethod,releasedate+from+ps+order+by+releasedate+desc+&format=json
# ...

# %%
print(list9a[:10][0]['pl_name'])
# Out:
# K2-114 b

# %%
values = [i['pl_name']+' : '+i['releasedate'] for i in list9a]

print(values[:10])
# Out:
# ['K2-114 b : 2024-11-21', 'K2-98 b : 2024-11-21', 'K2-277 b : 2024-11-21', 'K2-203 b : 2024-11-21', 'K2-204 b : 2024-11-21', 'K2-208 b : 2024-11-21', 'K2-211 b : 2024-11-21', 'K2-225 b : 2024-11-21', 'K2-226 b : 2024-11-21', 'K2-7 b : 2024-11-21']

# %%
values[0]
# Out:
# 'K2-114 b : 2024-11-21'

# %%
len(values)
# Out:
# 36557

# %%
decouv_planete = list(set(values))

# %%
decouv_planete[:10]
# Out:
# ['Kepler-330 b : 2016-05-10',
#  'Kepler-495 c : 2014-11-18',
#  'HAT-P-11 b : 2022-10-18',
#  'Kepler-51 c : 2018-09-06',
#  'Kepler-80 c : 2014-05-14',
#  'Kepler-819 b : 2016-05-10',
#  'Kepler-194 c : 2013-10-28',
#  'Kepler-15 b : 2019-04-18',
#  'Kepler-343 b : 2019-04-18',
#  'Kepler-212 b : 2019-04-18']

# %%
len(decouv_planete)
# Out:
# 35795

# %%
values[:10]
# Out:
# ['K2-114 b : 2024-11-21',
#  'K2-98 b : 2024-11-21',
#  'K2-277 b : 2024-11-21',
#  'K2-203 b : 2024-11-21',
#  'K2-204 b : 2024-11-21',
#  'K2-208 b : 2024-11-21',
#  'K2-211 b : 2024-11-21',
#  'K2-225 b : 2024-11-21',
#  'K2-226 b : 2024-11-21',
#  'K2-7 b : 2024-11-21']

# %%
list9a[:20][0]['pl_name']
# Out:
# 'K2-114 b'

# %%
list9a[:20][0]['releasedate']
# Out:
# '2024-11-21'

# %%
list10 = [{list9a[:20][0]['pl_name']:list9a[:20][0]['releasedate']}]

# %%
list10
# Out:
# [{'K2-114 b': '2024-11-21'}]

# %% [markdown]
# bigdict = list9a[0]
# interesting_keys = ('pl_name', 'releasedate')
# subdict = {x: bigdict[x] for x in interesting_keys if x in bigdict}
# subdict

# %%
bigdict = list9a[0] 
interesting_keys = ('pl_name', 'releasedate') 
subdict = {x: bigdict[x] for x in interesting_keys if x in bigdict} 
subdict
# Out:
# {'pl_name': 'K2-114 b', 'releasedate': '2024-11-21'}

# %%
bigdict = list9a[1] 
interesting_keys = ('pl_name', 'releasedate') 
subdict = {x: bigdict[x] for x in interesting_keys if x in bigdict} 
subdict
# Out:
# {'pl_name': 'K2-98 b', 'releasedate': '2024-11-21'}

# %%
list9a[:5]
# Out:
# [{'pl_name': 'K2-114 b',
#   'hostname': 'K2-114',
#   'pl_letter': 'b',
#   'pl_bmasse': 638.8351,
#   'pl_bmassj': 2.01,
#   'pl_rade': 10.592,
#   'pl_radj': 0.945,
#   'pl_orbper': 11.390931,
#   'pl_dens': 2.96,
#   'pl_trandur': 3.9696,
#   'pl_ratror': 0.1167,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 0.86,
#   'st_lum': -0.444,
#   'st_age': 7.6,
#   'st_dens': 2.11,
#   'sy_dist': 475.758,
#   'disc_year': 2017,
#   'disc_telescope': '0.95 m Kepler Telescope',
#   'discoverymethod': 'Transit',
#   'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-98 b',
#   'hostname': 'K2-98',
#   'pl_letter': 'b',
#   'pl_bmasse': 34.00764,
#   'pl_bmassj': 0.107,
#   'pl_rade': 5.066,
#   'pl_radj': 0.452,
#   'pl_orbper': 10.1367349,
#   'pl_dens': 1.4,
#   'pl_trandur': 5.1216,
#   'pl_ratror': 0.03049,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.25,
#   'st_lum': 0.504,
#   'st_age': 3.4,
#   'st_dens': 0.499,
# ...

# %%
listp1 =[]
interesting_keys = ('pl_name', 'releasedate') 
for i in range(0,20):
    bigdict = list9a[i] 
    subdict = {x: bigdict[x] for x in interesting_keys if x in bigdict}
    listp1.append(subdict)
    i+=1
subdict
listp1
# Out:
# [{'pl_name': 'K2-114 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-98 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-277 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-203 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-204 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-208 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-211 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-225 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-226 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-7 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-147 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-237 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-250 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-260 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-261 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-321 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'HAT-P-11 b', 'releasedate': '2024-11-21'},
# ...

# %%
#suppression doublons
listp2=[dict(t) for t in {tuple(d.items()) for d in listp1}]
listp2
# Out:
# [{'pl_name': 'K2-208 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-226 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-204 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-261 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'HAT-P-11 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-237 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-260 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-277 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-211 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'HD 118203 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'HAT-P-11 c', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-147 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-250 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-7 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-114 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-321 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-203 b', 'releasedate': '2024-11-21'},
# ...

# %%
#tri par releasedate
newlist = sorted(listp2, key=lambda d: d['releasedate'],reverse=True)
newlist
# Out:
# [{'pl_name': 'K2-208 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-226 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-204 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-261 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'HAT-P-11 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-237 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-260 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-277 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-211 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'HD 118203 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'HAT-P-11 c', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-147 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-250 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-7 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-114 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-321 b', 'releasedate': '2024-11-21'},
#  {'pl_name': 'K2-203 b', 'releasedate': '2024-11-21'},
# ...

# %%
list7[:5]
# Out:
# [{'pl_name': 'OGLE-TR-10 b',
#   'hostname': 'OGLE-TR-10',
#   'pl_letter': 'b',
#   'pl_bmasse': 197.046,
#   'pl_bmassj': 0.62,
#   'pl_rade': 14.011,
#   'pl_radj': 1.25,
#   'pl_orbper': 3.101278,
#   'pl_dens': 0.4,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 1.14,
#   'st_lum': 0.188,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 1344.97,
#   'disc_year': 2004,
#   'disc_telescope': '1.3 m Warsaw University Telescope',
#   'discoverymethod': 'Transit',
#   'releasedate': '2014-05-14'},
#  {'pl_name': 'BD-08 2823 c',
#   'hostname': 'BD-08 2823',
#   'pl_letter': 'c',
#   'pl_bmasse': 104.0,
#   'pl_bmassj': 0.33,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 237.6,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 2,
#   'sy_mnum': 0,
#   'st_mass': 0.74,
#   'st_lum': None,
#   'st_age': 4.5,
#   'st_dens': None,
# ...

# %%
newlist7 = sorted(list7, key=lambda d: d['pl_name'])
newlist7[:10]
# Out:
# [{'pl_name': '11 Com b',
#   'hostname': '11 Com',
#   'pl_letter': 'b',
#   'pl_bmasse': 4914.89849,
#   'pl_bmassj': 15.464,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 323.21,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 2,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 2.09,
#   'st_lum': 1.978,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 93.1846,
#   'disc_year': 2007,
#   'disc_telescope': '2.16 m Telescope',
#   'discoverymethod': 'Radial Velocity',
#   'releasedate': '2023-09-19'},
#  {'pl_name': '11 UMi b',
#   'hostname': '11 UMi',
#   'pl_letter': 'b',
#   'pl_bmasse': 4684.8142,
#   'pl_bmassj': 14.74,
#   'pl_rade': None,
#   'pl_radj': None,
#   'pl_orbper': 516.21997,
#   'pl_dens': None,
#   'pl_trandur': None,
#   'pl_ratror': None,
#   'sy_snum': 1,
#   'sy_pnum': 1,
#   'sy_mnum': 0,
#   'st_mass': 2.78,
#   'st_lum': None,
#   'st_age': None,
#   'st_dens': None,
#   'sy_dist': 125.321,
# ...

# %%
def search(name):
    for p in newlist7:
        if p['pl_name'] == name:
            return p

search('Proxima Cen b')
# Out:
# {'pl_name': 'Proxima Cen b',
#  'hostname': 'Proxima Cen',
#  'pl_letter': 'b',
#  'pl_bmasse': 1.07,
#  'pl_bmassj': 0.00337,
#  'pl_rade': None,
#  'pl_radj': None,
#  'pl_orbper': 11.1868,
#  'pl_dens': None,
#  'pl_trandur': None,
#  'pl_ratror': None,
#  'sy_snum': 3,
#  'sy_pnum': 1,
#  'sy_mnum': 0,
#  'st_mass': 0.12,
#  'st_lum': -2.796,
#  'st_age': None,
#  'st_dens': None,
#  'sy_dist': 1.30119,
#  'disc_year': 2016,
#  'disc_telescope': 'Multiple Telescopes',
#  'discoverymethod': 'Radial Velocity',
#  'releasedate': '2023-05-15'}

# %%
len(list7)
# Out:
# 5788

# %%
urlexo14g = "https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+\
pl_name,hostname,pl_letter,pl_bmasse,pl_bmassj,pl_rade,pl_radj,pl_orbper,pl_dens,pl_trandur,pl_ratror,\
sy_snum,sy_pnum,sy_mnum,st_mass,st_lum,st_age,st_dens,sy_dist,disc_year,disc_telescope,discoverymethod,\
releasedate,disc_pubdate\
+from+ps+order+by+disc_pubdate+desc+&format=json"

# %%
print(urlexo14g)
list14g = json.loads(urlopen(urlexo14g).read().decode("utf-8"))
print(list14g[:10])
# Out:
# https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+pl_name,hostname,pl_letter,pl_bmasse,pl_bmassj,pl_rade,pl_radj,pl_orbper,pl_dens,pl_trandur,pl_ratror,sy_snum,sy_pnum,sy_mnum,st_mass,st_lum,st_age,st_dens,sy_dist,disc_year,disc_telescope,discoverymethod,releasedate,disc_pubdate+from+ps+order+by+disc_pubdate+desc+&format=json
# ...

# %%
values14g = [i['pl_name']+' : '+i['disc_pubdate'] for i in list14g]

print(values14g[:10])
# Out:
# ['Kepler-879 c : 2024-11', 'KOI-4978 b : 2024-11', 'Kepler-1489 c : 2024-11', 'TOI-6651 b : 2024-11', 'TOI-6651 b : 2024-11', 'Kepler-963 c : 2024-11', 'Kepler-158 d : 2024-11', 'TOI-2274 b : 2024-10', 'TOI-1883 b : 2024-10', 'TOI-2384 b : 2024-10']

# %%
len(values14g)
# Out:
# 36557

# %%
decouv_planete14g = list(set(values14g))
decouv_planete14g[:5]
# Out:
# ['Kepler-1197 b : 2016-05',
#  'TOI-2180 b : 2022-02',
#  'HU Aqr AB b : 2011-06',
#  'Kepler-1658 b : 2019-05',
#  'Kepler-259 b : 2014-03']

# %%
listp14g =[]
interesting_keys = ('pl_name', 'disc_pubdate') 
for i in range(0,20):
    bigdict = list14g[i] 
    subdict = {x: bigdict[x] for x in interesting_keys if x in bigdict}
    listp14g.append(subdict)
    i+=1
subdict
listp14g
# Out:
# [{'pl_name': 'Kepler-879 c', 'disc_pubdate': '2024-11'},
#  {'pl_name': 'KOI-4978 b', 'disc_pubdate': '2024-11'},
#  {'pl_name': 'Kepler-1489 c', 'disc_pubdate': '2024-11'},
#  {'pl_name': 'TOI-6651 b', 'disc_pubdate': '2024-11'},
#  {'pl_name': 'TOI-6651 b', 'disc_pubdate': '2024-11'},
#  {'pl_name': 'Kepler-963 c', 'disc_pubdate': '2024-11'},
#  {'pl_name': 'Kepler-158 d', 'disc_pubdate': '2024-11'},
#  {'pl_name': 'TOI-2274 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'TOI-1883 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'TOI-2384 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'TOI-2379 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'TOI-2384 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'TOI-2379 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'TOI-2420 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'TOI-2485 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'TOI-2420 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'TOI-2485 b', 'disc_pubdate': '2024-10'},
# ...

# %%
#suppression doublons
listp214g=[dict(t) for t in {tuple(d.items()) for d in listp14g}]
listp214g
# Out:
# [{'pl_name': 'KOI-4978 b', 'disc_pubdate': '2024-11'},
#  {'pl_name': 'Kepler-963 c', 'disc_pubdate': '2024-11'},
#  {'pl_name': 'Kepler-158 d', 'disc_pubdate': '2024-11'},
#  {'pl_name': 'TOI-2274 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'TOI-2379 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'TOI-2420 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'Barnard b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'TOI-1883 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'Kepler-51 e', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'TOI-2384 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'TOI-6651 b', 'disc_pubdate': '2024-11'},
#  {'pl_name': 'TOI-2485 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'Kepler-1489 c', 'disc_pubdate': '2024-11'},
#  {'pl_name': 'TOI-2768 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'Kepler-879 c', 'disc_pubdate': '2024-11'}]

# %%
#tri par disc_pubdate
newlist14g = sorted(listp214g, key=lambda d: d['disc_pubdate'],reverse=True)
newlist14g
# Out:
# [{'pl_name': 'KOI-4978 b', 'disc_pubdate': '2024-11'},
#  {'pl_name': 'Kepler-963 c', 'disc_pubdate': '2024-11'},
#  {'pl_name': 'Kepler-158 d', 'disc_pubdate': '2024-11'},
#  {'pl_name': 'TOI-6651 b', 'disc_pubdate': '2024-11'},
#  {'pl_name': 'Kepler-1489 c', 'disc_pubdate': '2024-11'},
#  {'pl_name': 'Kepler-879 c', 'disc_pubdate': '2024-11'},
#  {'pl_name': 'TOI-2274 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'TOI-2379 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'TOI-2420 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'Barnard b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'TOI-1883 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'Kepler-51 e', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'TOI-2384 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'TOI-2485 b', 'disc_pubdate': '2024-10'},
#  {'pl_name': 'TOI-2768 b', 'disc_pubdate': '2024-10'}]

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make the data
np.random.seed(3)
x = 4 + np.random.normal(0, 2, 24)
y = 4 + np.random.normal(0, 2, len(x))
print("x: " ,x)
print("y: " ,y)
# size and color:
sizes = np.random.uniform(15, 80, len(x))
colors = np.random.uniform(15, 80, len(x))
print("sizes: " ,sizes)
print("colors: " ,colors)
# plot
fig, ax = plt.subplots()

ax.scatter(x, y, s=sizes, c=colors, vmin=0, vmax=100)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()
# Out:
# x:  [7.57725695 4.8730197  4.19299494 0.27301459 3.44522359 3.29048204
#  3.83451704 2.74599865 3.91236366 3.04556394 1.37227049 5.76924476
#  5.76263608 7.41914613 4.10006728 3.19064517 2.9092801  0.90704537
#  5.96473487 1.79786474 1.62990695 3.5887002  6.97229671 4.47343253]
# y:  [ 1.95242972  2.5740136   5.25048993  3.67897327  2.4623273   3.53993856
#   5.49011253  7.95222157  1.51175334  2.74716618  2.39246781 -0.83816635
#   2.15241596  1.95224848  6.24795592  3.73617153  0.75342911  5.2933509
#   3.28745848  0.51371793  2.80670072  2.82281124  2.2522354   4.05942763]
# sizes:  [46.4330596  38.54145381 60.99963042 63.5385045  59.92103992 59.79672689
#  39.28400807 58.42876231 37.09016316 52.23160154 36.17746527 43.9344282
#  18.9993805  30.77390244 78.1541694  29.98797328 59.94603821 57.28099578
#  62.05604406 45.88075969 53.78314535 19.35301256 19.71653896 27.93344171]
# colors:  [24.87096481 21.5067824  23.4041012  50.96305257 27.20796362 76.8865808
# ...
